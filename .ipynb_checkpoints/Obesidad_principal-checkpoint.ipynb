# %%
import pandas as pd
import numpy as np
import matplotlib
from plotnine import *
import plotly.express as px
import imageio.v2 as imageio
import os
import plotly.io as pio

# %% [markdown]
# # Carga de los datos

# %%
obesidad = pd.read_csv("Data/obesity.csv")

# %% [markdown]
# |Variable Name|	Role|	Type	|Demographic	|Description|	Units	|Missing Values|
# |----------|:---------|:---------|:---------|:---------|:---------|:---------|
# |Gender|	Feature|	Categorical|	Gender|			| |no|
# |Age|	Feature|	Continuous|	Age|	 |		|no|
# |Height|	Feature|	Continuous|		 |		| |no|
# |Weight|	Feature|	Continuous|		 |		| |no|
# |family_history_with_overweight|	Feature|	Binary|	| 	Has a family member suffered or suffers from overweight?|		|no|
# |FAVC|	Feature|	Binary|	  | Do you eat high caloric food frequently?|		|no|
# |FCVC|	Feature|	Integer|	 | Do you usually eat vegetables in your meals?|		|no|
# |NCP|	Feature|	Continuous|	 | How many main meals do you have daily?|		|no|
# |CAEC|	Feature|	Categorical|  | Do you eat any food between meals?|		|no|
# |SMOKE|	Feature|	Binary|	| Do you smoke?|		|no|
# |CH2O|	Feature|	Continuous|		|How much water do you drink daily?|		|no|
# |SCC|	Feature|	Binary|		|Do you monitor the calories you eat daily?|		|no|
# |FAF|	Feature|	Continuous|		|How often do you have physical activity?|		|no|
# |TUE|	Feature|	Integer|		|How much time do you use technological devices such as cell phone, videogames, television, computer and others?|		|no|
# |CALC|	Feature|	Categorical|		|How often do you drink alcohol?|		|no|
# |MTRANS|	Feature|	Categorical|		|Which transportation do you usually use?|		|no|
# |NObeyesdad|	Target|	Categorical|		|Obesity level|		|no|

# %% [markdown]
# # Procesado de los datos

# %%
obesidad.head(10)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
# 5    Male  29.0    1.62    53.0                             no  yes   2.0
# 6  Female  23.0    1.50    55.0                            yes  yes   3.0
# 7    Male  22.0    1.64    53.0                             no   no   2.0
# 8    Male  24.0    1.78    64.0                            yes  yes   3.0
# 9    Male  22.0    1.72    68.0                            yes  yes   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 5  3.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
# 6  3.0  Sometimes    no   2.0   no  1.0  0.0   Sometimes
# 7  3.0  Sometimes    no   2.0   no  3.0  0.0   Sometimes
# 8  3.0  Sometimes    no   2.0   no  1.0  1.0  Frequently
# 9  3.0  Sometimes    no   2.0   no  1.0  1.0          no
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II
# 5             Automobile        Normal_Weight
# 6              Motorbike        Normal_Weight
# 7  Public_Transportation        Normal_Weight
# 8  Public_Transportation        Normal_Weight
# 9  Public_Transportation        Normal_Weight

# %%
obesidad.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %% [markdown]
# Cambiamos el nombre de las columnas para facilitar la comprensión

# %%
obesidad.columns = ['gender', 'age', 'height', 'weight', 'family_history_with_overweight',
       'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
       'CALC', 'MTRANS', 'obesity_type']

# %% [markdown]
# En principio no tiene NAs, pero vamos a asegurarnos

# %%
obesidad_sin_nulos = obesidad.dropna()

# %% [markdown]
# Veamos si sus caracteristicas sin las mismas

# %%
print(obesidad_sin_nulos.shape,obesidad.shape,'son iguales')
# Out:
# (2111, 17) (2111, 17) son iguales

# %% [markdown]
# Ahora veamos si hay algun outlier o algún dato incorrecto

# %%
columnas_no_numericas=obesidad.select_dtypes(exclude='number').columns
for campo in columnas_no_numericas:
    print(obesidad[campo].unique())
print('Entre los campos no numéricos no se ve ningún elemento incorrecto, pero vamos a dar categorias para poder hacer\nuna buena visualizacion')
# Out:
# ['Female' 'Male']
# ['yes' 'no']
# ['no' 'yes']
# ['Sometimes' 'Frequently' 'Always' 'no']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'Sometimes' 'Frequently' 'Always']
# ['Public_Transportation' 'Walking' 'Automobile' 'Motorbike' 'Bike']
# ['Normal_Weight' 'Overweight_Level_I' 'Overweight_Level_II'
#  'Obesity_Type_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']
# Entre los campos no numéricos no se ve ningún elemento incorrecto, pero vamos a dar categorias para poder hacer
# una buena visualizacion

# %%
#Para tipos de obesidad
orden_categorias = ['Insufficient_Weight','Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II',
       'Obesity_Type_III']
obesidad['obesity_type'] = pd.Categorical(obesidad['obesity_type'], categories=orden_categorias, ordered=True)
#Para CAEC, ¿comes entre comidas?
orden_categorias = ['no', 'Sometimes', 'Frequently', 'Always']
obesidad['CAEC'] = pd.Categorical(obesidad['CAEC'], categories=orden_categorias, ordered=True)
#Para CALC, ¿bebes alcohol?
orden_categorias = ['no', 'Sometimes', 'Frequently', 'Always']
obesidad['CALC'] = pd.Categorical(obesidad['CALC'], categories=orden_categorias, ordered=True)

# %% [markdown]
# Ahora estudiemos las numéricas

# %%
obesidad.select_dtypes(include='number').describe()
# Out:
#                age       height       weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# 75%       2.477420     1.666678     1.000000
# max       3.000000     3.000000     2.000000

# %% [markdown]
# Se puede observar que hay mucha gente joven en el estudio, y muy poca muestra para gente mayor

# %%
print(ggplot(obesidad, aes(x='age')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='Edad')
)
print('La mayoria de la gente es muy joven, hay baja representatividad de personas mayores')
# Out:
# La mayoria de la gente es muy joven, hay baja representatividad de personas mayores

# %%
(ggplot(obesidad, aes(x='gender', y='age')) +
 geom_boxplot())
# Out:
# <Figure Size: (640 x 480)>

# %%
print('A partir de los 40 años se tiene muy poca representatividad de esta parte la población,\nes por ello que quitamos esos resultados')
obesidad=obesidad.loc[obesidad['age']<=40]
# Out:
# A partir de los 40 años se tiene muy poca representatividad de esta parte la población,
# es por ello que quitamos esos resultados

# %%
print(ggplot(obesidad, aes(x='weight')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='Peso')
)
print('Los datos dados sobre el peso son correctos, tiene un distribución lógica')
# Out:
# Los datos dados sobre el peso son correctos, tiene un distribución lógica

# %%
print(ggplot(obesidad, aes(x='height')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='Altura')
)
print('Los datos dados sobre la altura son correctos, tiene un distribución lógica')
# Out:
# Los datos dados sobre la altura son correctos, tiene un distribución lógica

# %%
print(ggplot(obesidad, aes(x='FCVC')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='¿Comes normalmente en tus comidas verduras?')
)
print('Este campo debe ser categórico, se va a transformar para obtener dicho resultado')
# Out:
# Este campo debe ser categórico, se va a transformar para obtener dicho resultado

# %%
def vegetales(verdura):
    if verdura <= 1.5:
        return "Nunca"
    elif verdura <= 2.5:
        return "Algunas veces"
    else:
        return "Siempre"

obesidad['vegetables'] = obesidad['FCVC'].apply(vegetales)
orden_categorias = ["Nunca","Algunas veces","Siempre"]
obesidad['vegetables'] = pd.Categorical(obesidad['vegetables'], categories=orden_categorias, ordered=True)
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\2898178892.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\2898178892.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(obesidad['vegetables'].unique())
# Out:
# ['Algunas veces', 'Siempre', 'Nunca']
# Categories (3, object): ['Nunca' < 'Algunas veces' < 'Siempre']

# %%
print(ggplot(obesidad, aes(x='NCP')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='¿Cuantas comidas principales tienes en el dia?')
)
print('Este campo debe ser categórico, se va a transformar para obtener dicho resultado')
# Out:
# Este campo debe ser categórico, se va a transformar para obtener dicho resultado

# %%
def comidas(comida):
    if comida <= 2:
        return "Entre 1 y 2"
    elif comida <= 3.5:
        return "Tres"
    else:
        return "Más de tres"

obesidad['comidas'] = obesidad['NCP'].apply(comidas)
orden_categorias = ["Entre 1 y 2","Tres","Más de tres"]
obesidad['comidas'] = pd.Categorical(obesidad['comidas'], categories=orden_categorias, ordered=True)
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\3754721060.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\3754721060.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(obesidad['comidas'].unique())
# Out:
# ['Tres', 'Entre 1 y 2', 'Más de tres']
# Categories (3, object): ['Entre 1 y 2' < 'Tres' < 'Más de tres']

# %%
print(ggplot(obesidad, aes(x='CH2O')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='¿Cuanta agua bebes durante el día?')
)
print('Este campo debe ser categórico, se va a transformar para obtener dicho resultado')
# Out:
# Este campo debe ser categórico, se va a transformar para obtener dicho resultado

# %%
def litros(agua):
    if agua <= 1.5:
        return "Menos de 1L"
    elif agua <= 2.5:
        return "1L-2L"
    else:
        return "Más de 2L"

obesidad['water'] = obesidad['CH2O'].apply(litros)
orden_categorias = ["Menos de 1L","1L-2L","Más de 2L"]
obesidad['water'] = pd.Categorical(obesidad['water'], categories=orden_categorias, ordered=True)
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\4265755954.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\4265755954.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(obesidad['water'].unique())
# Out:
# ['1L-2L', 'Más de 2L', 'Menos de 1L']
# Categories (3, object): ['Menos de 1L' < '1L-2L' < 'Más de 2L']

# %%
print(ggplot(obesidad, aes(x='FAF')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(x='Días',title='¿Haces a menudo actividad física?')
)
print('Este campo debe ser categórico, se va a transformar para obtener dicho resultado')
# Out:
# Este campo debe ser categórico, se va a transformar para obtener dicho resultado

# %%
def ejercicio(deporte):
    if deporte <= 0.5:
        return "No hago"
    elif deporte <= 1.5:
        return "1d-2d"
    elif deporte <= 2.5:
        return "2d-4d"
    else:
        return "4d-5d"

obesidad['physical_activity'] = obesidad['FAF'].apply(ejercicio)
orden_categorias = ["No hago","1d-2d","2d-4d","4d-5d"]
obesidad['physical_activity'] = pd.Categorical(obesidad['physical_activity'], categories=orden_categorias, ordered=True)
print(obesidad['physical_activity'].unique())
# Out:
# ['No hago', '4d-5d', '2d-4d', '1d-2d']
# Categories (4, object): ['No hago' < '1d-2d' < '2d-4d' < '4d-5d']
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\2116157306.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\2116157306.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(ggplot(obesidad, aes(x='TUE')) + 
      geom_density(fill='red',alpha=0.5)+
 labs(title='¿Cuanto tiempo gastas consumiendo dispositivos electronicos?')
)
print('Este campo debe ser categórico, se va a transformar para obtener dicho resultado')
# Out:
# Este campo debe ser categórico, se va a transformar para obtener dicho resultado

# %%
def electronica(movil):
    if movil <= 0.5:
        return "0-2h"
    elif movil <= 1.5:
        return "3-5h"
    else:
        return "Más de 5h"

obesidad['electronica'] = obesidad['TUE'].apply(electronica)
orden_categorias = ["0-2h","3-5h","Más de 5h"]
obesidad['electronica'] = pd.Categorical(obesidad['electronica'], categories=orden_categorias, ordered=True)
print(obesidad['electronica'].unique())
# Out:
# ['3-5h', '0-2h', 'Más de 5h']
# Categories (3, object): ['0-2h' < '3-5h' < 'Más de 5h']
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\2799942739.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\2799942739.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# De esta manera tenemos pasadas a categóricas todas la variable que deben de ser así

# %%
columnas_no_numericas=obesidad.select_dtypes(exclude='number').columns
for campo in columnas_no_numericas:
    print(obesidad[campo].unique())
print('Entre los campos no numéricos no se ve ningún elemento incorrecto')
# Out:
# ['Female' 'Male']
# ['yes' 'no']
# ['no' 'yes']
# ['Sometimes', 'Frequently', 'Always', 'no']
# Categories (4, object): ['no' < 'Sometimes' < 'Frequently' < 'Always']
# ['no' 'yes']
# ['no' 'yes']
# ['no', 'Sometimes', 'Frequently', 'Always']
# Categories (4, object): ['no' < 'Sometimes' < 'Frequently' < 'Always']
# ['Public_Transportation' 'Walking' 'Automobile' 'Motorbike' 'Bike']
# ['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II', 'Obesity_Type_III']
# Categories (7, object): ['Insufficient_Weight' < 'Normal_Weight' < 'Overweight_Level_I' < 'Overweight_Level_II' < 'Obesity_Type_I' < 'Obesity_Type_II' < 'Obesity_Type_III']
# ['Algunas veces', 'Siempre', 'Nunca']
# Categories (3, object): ['Nunca' < 'Algunas veces' < 'Siempre']
# ['Tres', 'Entre 1 y 2', 'Más de tres']
# Categories (3, object): ['Entre 1 y 2' < 'Tres' < 'Más de tres']
# ['1L-2L', 'Más de 2L', 'Menos de 1L']
# Categories (3, object): ['Menos de 1L' < '1L-2L' < 'Más de 2L']
# ['No hago', '4d-5d', '2d-4d', '1d-2d']
# Categories (4, object): ['No hago' < '1d-2d' < '2d-4d' < '4d-5d']
# ['3-5h', '0-2h', 'Más de 5h']
# Categories (3, object): ['0-2h' < '3-5h' < 'Más de 5h']
# Entre los campos no numéricos no se ve ningún elemento incorrecto

# %%
obesidad.rename(columns={'CALC':'alcohol'}, inplace=True)
obesidad_limpio=obesidad[['gender', 'age', 'height', 'weight', 'family_history_with_overweight','FAVC','vegetables','comidas','CAEC','SMOKE','water','SCC','physical_activity','electronica','alcohol','obesity_type']]
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\3686228969.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
obesidad_limpio.head(3)
# Out:
#    gender   age  height  weight family_history_with_overweight FAVC  \
# 0  Female  21.0    1.62    64.0                            yes   no
# 1  Female  21.0    1.52    56.0                            yes   no
# 2    Male  23.0    1.80    77.0                            yes   no
#
#       vegetables comidas       CAEC SMOKE      water  SCC physical_activity  \
# 0  Algunas veces    Tres  Sometimes    no      1L-2L   no           No hago
# 1        Siempre    Tres  Sometimes   yes  Más de 2L  yes             4d-5d
# 2  Algunas veces    Tres  Sometimes    no      1L-2L   no             2d-4d
#
#   electronica     alcohol   obesity_type
# 0        3-5h          no  Normal_Weight
# 1        0-2h   Sometimes  Normal_Weight
# 2        3-5h  Frequently  Normal_Weight

# %%
obesidad_limpio.to_csv('obesity_limpio.csv', index=False)

# %% [markdown]
# ### 1er Insight
#
# ¿Como evoluciona el nivel de ingesta de alcohol, actividad fisica, consumo de agua y vegetales según sea el nivel de obesidad?¿Hay algun patrón?

# %%
def fun(obesidad_limpio,columna,paleta):
    return (ggplot(obesidad_limpio[['obesity_type',columna]], aes(x='obesity_type', fill=f'factor({columna})')) + 
        geom_bar(position='dodge') + 
        theme(axis_text_x = element_text(angle = 45, hjust = 1,color = "black"),
              panel_grid_major_x=element_blank(),
              panel_background=element_rect(fill='grey'),
              panel_grid_major_y=element_blank(),
              panel_grid_minor_y=element_blank())+
        labs(x='Niveles de obesidad', y='Cantidad')+
        scale_fill_brewer(palette = paleta,name = f"Nivel de consumo de {columna}")+
        ylim(0, 300)
        )
fun(obesidad_limpio,'vegetables','Greens')
# Out:
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\layer.py:364: PlotnineWarning:
#
# geom_bar : Removed 1 rows containing missing values.
# <Figure Size: (640 x 480)>

# %%
fun(obesidad_limpio,'water','Blues')
# Out:
# <Figure Size: (640 x 480)>

# %%
fun(obesidad_limpio,'physical_activity','Purples')
# Out:
# <Figure Size: (640 x 480)>

# %%
fun(obesidad_limpio,'alcohol','YlOrRd')
# Out:
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\layer.py:364: PlotnineWarning:
#
# geom_bar : Removed 1 rows containing missing values.
# <Figure Size: (640 x 480)>

# %% [markdown]
# ### 2do Insight
#
# ¿Cuanta gente de cada grupo sigue una dieta sana(es decir bebe entre 1y 2 litros de agua, hace ejercicio de 2 a 4 dias por semana, no come mucho entre comidas, sin comida con muchas calorias, no fuma no usa demasiado los juegos, bebe a veces o nunca alcohol, comidas principales 3)?

# %%
dieta_sana_condiciones = (
    (obesidad_limpio['water'].isin(['1L-2L','Más de 2L'])) &
    (obesidad_limpio['physical_activity'].isin(['4d-5d', '2d-4d'])) &
    (obesidad_limpio['comidas']=="Tres") &
    (obesidad_limpio['FAVC'] == 'no') &
    (obesidad_limpio['SMOKE'] == 'no') &
    (obesidad_limpio['electronica']=='0-2h') &
    (obesidad_limpio['alcohol'].isin(['no', 'Sometimes'])) &
    (obesidad_limpio['CAEC'].isin(['no', 'Sometimes'])))

# %%
obesidad_limpio['Salud']='NA'
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\1805149038.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
obesidad_limpio.loc[dieta_sana_condiciones,'Salud']='Se cuida'

# %%
obesidad_limpio[dieta_sana_condiciones]
# Out:
#      gender   age  height  weight family_history_with_overweight FAVC  \
# 7      Male  22.0    1.64    53.0                             no   no
# 12     Male  22.0    1.65    56.0                             no   no
# 44     Male  21.0    1.81    80.0                             no   no
# 75   Female  23.0    1.63    45.0                            yes   no
# 83   Female  19.0    1.60    45.0                             no   no
# 96   Female  23.0    1.66    60.0                            yes   no
# 153    Male  34.0    1.69    84.0                            yes   no
# 192    Male  20.0    1.83    85.0                            yes   no
# 225    Male  25.0    1.83   121.0                            yes   no
# 255    Male  19.0    1.78    81.0                            yes   no
# 289    Male  19.0    1.88    79.0                             no   no
# 297    Male  26.0    1.74    80.0                             no   no
# 343    Male  23.0    1.65    66.0                             no   no
# 405    Male  18.0    1.74    86.0                             no   no
# 487    Male  20.0    1.84   104.0                            yes   no
#
#         vegetables comidas       CAEC SMOKE      water  SCC physical_activity  \
# 7    Algunas veces    Tres  Sometimes    no      1L-2L   no             4d-5d
# 12         Siempre    Tres  Sometimes    no  Más de 2L   no             2d-4d
# 44           Nunca    Tres         no    no      1L-2L   no             2d-4d
# 75         Siempre    Tres  Sometimes    no  Más de 2L  yes             2d-4d
# 83         Siempre    Tres         no    no  Más de 2L  yes             2d-4d
# 96   Algunas veces    Tres  Sometimes    no      1L-2L   no             4d-5d
# 153  Algunas veces    Tres  Sometimes    no  Más de 2L   no             2d-4d
# 192        Siempre    Tres  Sometimes    no  Más de 2L  yes             4d-5d
# 225        Siempre    Tres  Sometimes    no  Más de 2L   no             2d-4d
# 255          Nunca    Tres  Sometimes    no      1L-2L   no             4d-5d
# 289  Algunas veces    Tres  Sometimes    no  Más de 2L   no             4d-5d
# 297  Algunas veces    Tres  Sometimes    no      1L-2L   no             2d-4d
# 343        Siempre    Tres  Sometimes    no      1L-2L   no             4d-5d
# 405        Siempre    Tres  Sometimes    no      1L-2L   no             4d-5d
# 487  Algunas veces    Tres  Sometimes    no  Más de 2L   no             4d-5d
#
#     electronica    alcohol         obesity_type     Salud
# 7          0-2h  Sometimes        Normal_Weight  Se cuida
# 12         0-2h  Sometimes        Normal_Weight  Se cuida
# 44         0-2h         no        Normal_Weight  Se cuida
# 75         0-2h         no  Insufficient_Weight  Se cuida
# 83         0-2h         no  Insufficient_Weight  Se cuida
# 96         0-2h  Sometimes        Normal_Weight  Se cuida
# 153        0-2h         no  Overweight_Level_II  Se cuida
# 192        0-2h  Sometimes   Overweight_Level_I  Se cuida
# 225        0-2h  Sometimes      Obesity_Type_II  Se cuida
# 255        0-2h         no   Overweight_Level_I  Se cuida
# 289        0-2h  Sometimes        Normal_Weight  Se cuida
# 297        0-2h         no   Overweight_Level_I  Se cuida
# 343        0-2h         no        Normal_Weight  Se cuida
# 405        0-2h         no  Overweight_Level_II  Se cuida
# 487        0-2h         no       Obesity_Type_I  Se cuida

# %%
healthy_people=obesidad_limpio[dieta_sana_condiciones]#['obesity_type'].value_counts().reset_index()
healthy_people.shape
# Out:
# (15, 17)

# %%
dieta_normal_condiciones=(~dieta_sana_condiciones) & ((obesidad_limpio['water'].isin(['Menos de 1L','Más de 2L'])) &
    (obesidad_limpio['physical_activity'].isin(['No hago',])) &
    (obesidad_limpio['comidas'].isin(['Entre 1 y 2', 'Más de tres'])) &
    (obesidad_limpio['FAVC'] == 'yes')  &
    (obesidad_limpio['electronica']=='Más de 5h') &
    (obesidad_limpio['alcohol'].isin(['Frequently', 'Always'])) &
    (obesidad_limpio['CAEC'].isin(['Frequently', 'Always']))|
    (obesidad_limpio['SMOKE'] == 'yes'))

# %%
obesidad_limpio.loc[dieta_normal_condiciones,'Salud']='No se cuida'
obesidad_limpio.loc[(~dieta_normal_condiciones)&(~dieta_sana_condiciones),'Salud']='Fofisano'

# %%
obesidad_limpio['Salud'].value_counts().reset_index()
# Out:
#          Salud  count
# 0     Fofisano   1999
# 1  No se cuida     40
# 2     Se cuida     15

# %%
obesidad_limpio.columns
# Out:
# Index(['gender', 'age', 'height', 'weight', 'family_history_with_overweight',
#        'FAVC', 'vegetables', 'comidas', 'CAEC', 'SMOKE', 'water', 'SCC',
#        'physical_activity', 'electronica', 'alcohol', 'obesity_type', 'Salud'],
#       dtype='object')

# %%
fig = px.scatter(obesidad_limpio, x='weight', y='height', color='Salud', size='age',
                 labels={'weight': 'Peso', 'height': 'Altura'},
                 title='Scatter Plot con Plotly Express')

# Mostrar el gráfico
fig.show()
# Out:
# <div>                            <div id="5e1bacbf-5004-4198-a5b8-15bcefd9640c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e1bacbf-5004-4198-a5b8-15bcefd9640c")) {                    Plotly.newPlot(                        "5e1bacbf-5004-4198-a5b8-15bcefd9640c",                        [{"hovertemplate":"Salud=Fofisano<br>Peso=%{x}<br>Altura=%{y}<br>age=%{marker.size}<extra></extra>","legendgroup":"Fofisano","marker":{"color":"#636efa","size":[21.0,23.0,27.0,22.0,29.0,23.0,24.0,22.0,26.0,21.0,23.0,22.0,27.0,29.0,23.0,22.0,22.0,22.0,21.0,21.0,23.0,19.0,23.0,29.0,31.0,24.0,39.0,22.0,21.0,22.0,21.0,23.0,21.0,21.0,23.0,21.0,21.0,21.0,21.0,20.0,21.0,21.0,20.0,23.0,23.0,22.0,23.0,22.0,21.0,17.0,20.0,21.0,20.0,22.0,22.0,21.0,21.0,23.0,23.0,23.0,23.0,22.0,24.0,19.0,24.0,24.0,24.0,23.0,23.0,19.0,30.0,23.0,25.0,23.0,21.0,19.0,22.0,29.0,25.0,20.0,20.0,24.0,26.0,21.0,21.0,23.0,21.0,22.0,21.0,22.0,38.0,25.0,25.0,22.0,22.0,21.0,21.0,22.0,18.0,22.0,19.0,17.0,15.0,17.0,23.0,23.0,21.0,24.0,23.0,18.0,19.0,19.0,20.0,27.0,20.0,23.0,30.0,24.0,25.0,31.0,25.0,23.0,25.0,34.0,22.0,21.0,24.0,36.0,27.0,32.0,25.0,30.0,22.0,31.0,35.0,21.0,40.0,27.0,25.0,35.0,29.0,20.0,22.0,22.0,18.0,23.0,18.0,21.0,38.0,18.0,22.0,21.0,18.0,23.0,22.0,21.0,31.0,39.0,25.0,35.0,33.0,20.0,20.0,23.0,19.0,22.0,18.0,23.0,29.0,27.0,19.0,30.0,22.0,22.0,20.0,21.0,24.0,21.0,21.0,21.0,23.0,21.0,21.0,21.0,21.0,23.0,21.0,22.0,23.0,20.0,24.0,40.0,32.0,20.0,34.0,19.0,19.0,21.0,19.0,20.0,19.0,17.0,22.0,20.0,21.0,20.0,20.0,21.0,21.0,20.0,20.0,26.0,22.0,18.0,19.0,18.0,18.0,21.0,28.0,18.0,23.0,18.0,18.0,39.0,38.0,17.0,23.0,23.0,19.0,18.0,25.0,25.0,18.0,16.0,32.0,18.0,18.0,18.0,17.0,20.0,21.0,21.0,18.0,17.0,16.0,17.0,21.0,19.0,16.0,21.0,18.0,23.0,18.0,16.0,16.0,20.0,24.0,23.0,20.0,16.0,17.0,17.0,16.0,17.0,26.0,26.0,38.0,18.0,25.0,27.0,21.0,38.0,23.0,18.0,30.0,21.0,18.0,23.0,19.0,19.0,17.0,17.0,27.0,23.0,18.0,19.0,20.0,18.0,17.0,19.0,21.0,20.0,23.0,18.0,17.0,21.0,17.0,18.0,20.0,17.0,26.0,17.0,24.0,17.0,27.0,17.0,17.0,33.0,20.0,40.0,37.0,19.0,24.0,24.0,33.0,40.0,37.0,20.0,19.0,17.0,18.0,21.0,18.0,36.0,18.0,18.0,17.0,25.0,21.0,29.0,17.0,18.0,16.0,18.0,37.0,18.0,16.0,23.0,18.0,18.0,18.0,17.0,20.0,38.0,20.0,21.0,21.0,18.0,26.0,27.0,26.0,34.0,33.0,19.0,20.0,33.0,20.0,20.0,33.0,33.0,33.0,14.0,34.0,18.0,18.0,29.0,18.0,18.0,19.0,33.0,33.0,19.0,22.0,20.0,23.0,26.0,18.0,18.0,19.0,18.0,19.0,19.0,18.0,18.0,19.0,19.0,18.0,18.0,26.0,18.0,19.0,19.0,19.0,19.0,24.0,18.0,19.0,19.0,23.0,18.0,20.0,18.0,33.0,19.0,19.0,19.0,18.0,21.0,27.0,17.0,18.0,18.0,22.0,22.0,20.0,19.0,20.0,18.0,18.0,18.0,19.0,18.0,18.0,18.0,19.0,17.0,18.0,18.0,20.0,18.0,36.0,21.0,23.0,21.0,19.0,24.0,20.0,18.0,19.0,18.0,20.0,25.196214,18.503343,26.0,21.853826,21.90012,18.306615,26.0,26.0,21.849705,19.799054,17.188754,22.285024,22.0,21.02497,22.038327,21.243142,22.142432,21.962426,21.491055,22.717943,23.501249,18.535075,19.0,19.0,20.254534,21.0,20.225396,19.86997,20.147114,21.0,21.996523,21.376426,19.724106,23.0,22.851834,23.0,18.216032,21.81119,18.164768,18.871794,18.766033,18.540535,19.88036,19.717249,19.633898,23.0,20.406871,23.0,19.058511,18.827008,19.314964,29.970445,32.383858,24.163526,17.038222,16.30687,16.198153,18.0,18.0,18.0,17.486869,19.920629,18.426619,17.082867,17.000433,16.270434,17.908114,17.120699,19.329542,22.377998,20.954955,22.991668,19.300435,17.065445,19.084967,18.024853,19.833682,17.767432,19.504696,19.950605,19.0,17.0,17.0,18.525525,22.926352,21.785351,23.0,17.402028,18.0,18.48207,18.53084,19.94814,20.400053,19.556729,17.70368,18.274358,18.0,17.210933,17.469417,18.0,18.0,18.0,19.010211,19.091346,19.773303,19.483036,19.0,19.407204,18.0,18.424941,18.0,19.97981,21.798856,22.209706,23.018443,19.376997,20.971429,20.345161,20.519916,20.406066,21.478496,18.372563,19.931667,22.998709,18.006742, ...

# %% [markdown]
# ### 3er Insight
#
# ¿En cada grupo cómo es el uso de los moviles, hacen mucho deporte? Correlación entre uso de tecnología y actividad física

# %%
obesidad_limpio[['obesity_type','electronica']].value_counts().reset_index()
# Out:
#            obesity_type electronica  count
# 0      Obesity_Type_III        3-5h    215
# 1    Overweight_Level_I        0-2h    161
# 2       Obesity_Type_II        0-2h    161
# 3        Obesity_Type_I        0-2h    147
# 4   Overweight_Level_II        3-5h    143
# 5         Normal_Weight        0-2h    128
# 6   Insufficient_Weight        3-5h    127
# 7         Normal_Weight        3-5h    121
# 8        Obesity_Type_I        3-5h    119
# 9      Obesity_Type_III        0-2h    109
# 10      Obesity_Type_II        3-5h    103
# 11  Overweight_Level_II        0-2h    100
# 12  Insufficient_Weight        0-2h     94
# 13   Overweight_Level_I        3-5h     82
# 14       Obesity_Type_I   Más de 5h     61
# 15  Insufficient_Weight   Más de 5h     51
# 16   Overweight_Level_I   Más de 5h     44
# 17        Normal_Weight   Más de 5h     36
# 18  Overweight_Level_II   Más de 5h     31
# 19      Obesity_Type_II   Más de 5h     21

# %%
(ggplot(obesidad_limpio, aes(x = 'electronica', y = 'physical_activity',fill='obesity_type',size='Salud')) + 
  geom_jitter()+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
# <Figure Size: (640 x 480)>

# %%
for columna in obesidad_limpio.select_dtypes(exclude='number').columns[2:-1]:
    print(f'{columna}: ',obesidad_limpio[columna].unique())
# Out:
# FAVC:  ['no' 'yes']
# vegetables:  ['Algunas veces', 'Siempre', 'Nunca']
# Categories (3, object): ['Nunca' < 'Algunas veces' < 'Siempre']
# comidas:  ['Tres', 'Entre 1 y 2', 'Más de tres']
# Categories (3, object): ['Entre 1 y 2' < 'Tres' < 'Más de tres']
# CAEC:  ['Sometimes', 'Frequently', 'Always', 'no']
# Categories (4, object): ['no' < 'Sometimes' < 'Frequently' < 'Always']
# SMOKE:  ['no' 'yes']
# water:  ['1L-2L', 'Más de 2L', 'Menos de 1L']
# Categories (3, object): ['Menos de 1L' < '1L-2L' < 'Más de 2L']
# SCC:  ['no' 'yes']
# physical_activity:  ['No hago', '4d-5d', '2d-4d', '1d-2d']
# Categories (4, object): ['No hago' < '1d-2d' < '2d-4d' < '4d-5d']
# electronica:  ['3-5h', '0-2h', 'Más de 5h']
# Categories (3, object): ['0-2h' < '3-5h' < 'Más de 5h']
# alcohol:  ['no', 'Sometimes', 'Frequently', 'Always']
# Categories (4, object): ['no' < 'Sometimes' < 'Frequently' < 'Always']
# obesity_type:  ['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Insufficient_Weight', 'Obesity_Type_II', 'Obesity_Type_III']
# Categories (7, object): ['Insufficient_Weight' < 'Normal_Weight' < 'Overweight_Level_I' < 'Overweight_Level_II' < 'Obesity_Type_I' < 'Obesity_Type_II' < 'Obesity_Type_III']

# %% [markdown]
# ### 4º Insight
#
# ¿Qué Grupos de edades consumen más alcohol?

# %%
def crear_lista(paso):
    limite_inicial = 14
    limite_final = 40
    return list(zip(np.arange(limite_inicial, limite_final, paso), np.arange(limite_inicial + paso, limite_final + paso, paso)))

def encontrar_intervalo( elemento,lista_tuplas=crear_lista(5)):
    resultado = next((tupla for tupla in lista_tuplas if elemento >= tupla[0] and elemento < tupla[1]), None)
    return f'{resultado[0]}-{resultado[1]}'
obesidad_limpio['Intervalos_de_edad']=obesidad_limpio['age'].apply(encontrar_intervalo)
# Out:
# C:\Users\alexb\AppData\Local\Temp\ipykernel_23124\1190645986.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
obesidad_limpio
# Out:
#       gender        age    height      weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC     vegetables      comidas       CAEC SMOKE      water  SCC  \
# 0      no  Algunas veces         Tres  Sometimes    no      1L-2L   no
# 1      no        Siempre         Tres  Sometimes   yes  Más de 2L  yes
# 2      no  Algunas veces         Tres  Sometimes    no      1L-2L   no
# 3      no        Siempre         Tres  Sometimes    no      1L-2L   no
# 4      no  Algunas veces  Entre 1 y 2  Sometimes    no      1L-2L   no
# ...   ...            ...          ...        ...   ...        ...  ...
# 2106  yes        Siempre         Tres  Sometimes    no      1L-2L   no
# 2107  yes        Siempre         Tres  Sometimes    no      1L-2L   no
# 2108  yes        Siempre         Tres  Sometimes    no      1L-2L   no
# 2109  yes        Siempre         Tres  Sometimes    no  Más de 2L   no
# 2110  yes        Siempre         Tres  Sometimes    no  Más de 2L   no
#
#      physical_activity electronica     alcohol         obesity_type  \
# 0              No hago        3-5h          no        Normal_Weight
# 1                4d-5d        0-2h   Sometimes        Normal_Weight
# 2                2d-4d        3-5h  Frequently        Normal_Weight
# 3                2d-4d        0-2h  Frequently   Overweight_Level_I
# 4              No hago        0-2h   Sometimes  Overweight_Level_II
# ...                ...         ...         ...                  ...
# 2106             2d-4d        3-5h   Sometimes     Obesity_Type_III
# 2107             1d-2d        3-5h   Sometimes     Obesity_Type_III
# 2108             1d-2d        3-5h   Sometimes     Obesity_Type_III
# 2109             1d-2d        3-5h   Sometimes     Obesity_Type_III
# 2110             1d-2d        3-5h   Sometimes     Obesity_Type_III
#
#             Salud Intervalos_de_edad
# 0        Fofisano              19-24
# 1     No se cuida              19-24
# 2        Fofisano              19-24
# 3        Fofisano              24-29
# 4        Fofisano              19-24
# ...           ...                ...
# 2106     Fofisano              19-24
# 2107     Fofisano              19-24
# 2108     Fofisano              19-24
# 2109     Fofisano              24-29
# 2110     Fofisano              19-24
#
# [2054 rows x 18 columns]

# %%
(ggplot(obesidad_limpio, aes(x='Intervalos_de_edad', fill='alcohol')) + 
    geom_bar(position='fill')+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# <Figure Size: (640 x 480)>

# %%
list(obesidad_limpio['obesity_type'].cat.categories)
# Out:
# ['Insufficient_Weight',
#  'Normal_Weight',
#  'Overweight_Level_I',
#  'Overweight_Level_II',
#  'Obesity_Type_I',
#  'Obesity_Type_II',
#  'Obesity_Type_III']

# %%
def gif(filename,obesidad_limpio,x,y):
    def mostrar3(obesidad_limpio,obesity_type,x,y):
        p =(ggplot(obesidad_limpio.loc[obesidad_limpio['obesity_type'].isin(obesity_type)], aes(x = x, y = y,fill='obesity_type',size='Salud')) + 
      geom_jitter()+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
        p.save(filename=f'Imagenes/{obesity_type}.png', format='png')
        return f'Imagenes/{obesity_type}.png'

    #mostrar3(obesidad_limpio,'Normal_Weight')
    acum=[]
    image_files=[]
    for obesity_type in list(obesidad_limpio['obesity_type'].cat.categories):
        acum.append(obesity_type)
        image_files.append(mostrar3(obesidad_limpio,acum,x=x,y=y))

    #image_files = [mostrar3(obesidad_limpio,obesity_type) for obesity_type in list(obesidad_limpio['obesity_type'].unique())]

    with imageio.get_writer(f'{filename}.gif', duration=2.5) as writer:
        for filename in image_files:
            image = imageio.imread(filename)
            writer.append_data(image)

    # Elimina los archivos temporales
    for filename in image_files:
        os.remove(filename)

# %%
gif('Insight4',obesidad_limpio,x = 'Intervalos_de_edad', y = 'alcohol')
gif('Insight4.1',obesidad_limpio,x = 'water', y = 'alcohol')
# Out:
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II', 'Obesity_Type_III'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:587: PlotnineWarning:
#
# Saving 6.4 x 4.8 in image.
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\ggplot.py:588: PlotnineWarning:
#
# Filename: Imagenes/['Insufficient_Weight', 'Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_I', 'Obesity_Type_II', 'Obesity_Type_III'].png
#
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.

# %%
(ggplot(obesidad_limpio.loc[obesidad_limpio['obesity_type']=='Insufficient_Weight'], aes(x = 'Intervalos_de_edad', y = 'alcohol',fill='obesity_type',size='Salud')) + 
  geom_jitter()+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
# <Figure Size: (640 x 480)>

# %%
(ggplot(obesidad_limpio, aes(x = 'water', y = 'alcohol',fill='obesity_type',size='Salud')) + 
  geom_jitter()+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# C:\Users\alexb\anaconda3\Lib\site-packages\plotnine\scales\scale_size.py:49: PlotnineWarning:
#
# Using size for a discrete variable is not advised.
# <Figure Size: (640 x 480)>

# %%
obesidad_limpio.groupby(['obesity_type','water','alcohol']).count()['gender'].reset_index()
# Out:
#            obesity_type        water     alcohol  gender
# 0   Insufficient_Weight  Menos de 1L          no      16
# 1   Insufficient_Weight  Menos de 1L   Sometimes      67
# 2   Insufficient_Weight  Menos de 1L  Frequently       1
# 3   Insufficient_Weight  Menos de 1L      Always       0
# 4   Insufficient_Weight        1L-2L          no      71
# ..                  ...          ...         ...     ...
# 79     Obesity_Type_III        1L-2L      Always       0
# 80     Obesity_Type_III    Más de 2L          no       1
# 81     Obesity_Type_III    Más de 2L   Sometimes     148
# 82     Obesity_Type_III    Más de 2L  Frequently       0
# 83     Obesity_Type_III    Más de 2L      Always       0
#
# [84 rows x 4 columns]

# %%
def heatmap(obesidad_limpio,obesity_type,graficar=False):
        agua_ordenada_para_grafico=['Más de 2L','1L-2L','Menos de 1L']
        tabla_pivote = pd.pivot_table(obesidad_limpio.loc[obesidad_limpio['obesity_type']==obesity_type,['water','alcohol']], aggfunc=len, index='water', columns='alcohol', fill_value=0).reindex(agua_ordenada_para_grafico)
        fig = px.imshow(tabla_pivote,
                        labels=dict(x="Alcohol", y="Water", color="Frequency"),
                        x=tabla_pivote.columns,
                        y=tabla_pivote.index,
                        color_continuous_scale="Viridis",zmin=0, zmax=160)
        fig.update_layout(title=dict(text=f"<b>Heatmap para {obesity_type}</b>", x=0.5))
        pio.write_image(fig, f'Imagenes/{obesity_type}.png')
        if graficar:
            fig.show()
        else:
            return f'Imagenes/{obesity_type}.png'


def gif4_1(obesidad_limpio,filename):
    image_files = [heatmap(obesidad_limpio,obesity_type) for obesity_type in list(obesidad_limpio['obesity_type'].cat.categories)]
    with imageio.get_writer(f'{filename}.gif', duration=2.5) as writer:
        for filename in image_files:
            image = imageio.imread(filename)
            writer.append_data(image)

    # Elimina los archivos temporales
    for filename in image_files:
        os.remove(filename)   
        
#gif4_1(obesidad_limpio,'Insight4_1')
heatmap(obesidad_limpio,'Obesity_Type_III',True)
# Out:
# <div>                            <div id="d2b5a8a3-03e7-4b3d-8cde-a59e7a811d64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2b5a8a3-03e7-4b3d-8cde-a59e7a811d64")) {                    Plotly.newPlot(                        "d2b5a8a3-03e7-4b3d-8cde-a59e7a811d64",                        [{"coloraxis":"coloraxis","name":"0","x":["no","Sometimes"],"y":["M\u00e1s de 2L","1L-2L","Menos de 1L"],"z":[[1,148],[0,114],[0,61]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Alcohol: %{x}<br>Water: %{y}<br>Frequency: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"over ...

# %% [markdown]
# ## 5º y 6º Insight
# En base a la edad, como se distribuye el nivel de obesidad( no sabemos si puede salir mal, debido a lo mencionado en el paper)
#
#
# Podría ser interesante saber si hay algún género con más tendencia a la obesidad. Según tengo entendido, vi algún estudio alguna vez que decía que si eras hombre o mujer tenías más tendencia a ser obeso, no me acuerdo cual concretamente

# %%
(ggplot(obesidad_limpio.loc[obesidad_limpio['gender']=='Male'], aes(x='Intervalos_de_edad', fill='obesity_type')) + 
    geom_bar(position='fill')+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(obesidad_limpio.loc[obesidad_limpio['gender']!='Male'], aes(x='Intervalos_de_edad', fill='obesity_type')) + 
    geom_bar(position='fill')+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# 7. La retención de grasa tiene un factor genético importante y además el hecho de coger también los malos hábitos alimentarios que puede haber en tu casa, así que podríamos ver la proporción de gente obesa que tienen familiares obesos frente a la que no para saber hasta que punto puede ser un factor influyente

# %%
obesidad_limpio.groupby(["obesity_type", "family_history_with_overweight",'Salud']).size().reset_index(name='count')
(ggplot(obesidad_limpio, aes(x='Salud', fill='family_history_with_overweight')) + 
    geom_bar(position='fill')+scale_fill_brewer(type ='diverging',palette='RdYlBu',direction = -1))
# Out:
# <Figure Size: (640 x 480)>

# %%
def historial_familiar(obesidad_limpio,historial):
    obsidad_historial=obesidad_limpio.loc[obesidad_limpio['family_history_with_overweight']==historial].groupby(["obesity_type",'Salud']).size().reset_index(name='count')
    return(ggplot(obsidad_historial, aes(x='obesity_type', y='count')) + geom_bar(stat='identity',fill='Blue') +
        labs(x='Tipo de Obesidad', y='Cuenta', title='Observaciones por Tipo de Obesidad con Condiciones') +
        theme_bw() +
        theme(axis_text_x=element_text(rotation=55,hjust=1))) + theme(panel_grid = element_blank()) 

historial_familiar(obesidad_limpio,'no')
# Out:
# <Figure Size: (640 x 480)>

# %%
historial_familiar(obesidad_limpio,'yes')
# Out:
# <Figure Size: (640 x 480)>

# %%
def heatmap(obesidad_limpio):
        tabla_pivote = pd.pivot_table(obesidad_limpio[['physical_activity','water']], aggfunc=len, index='water', columns='physical_activity', fill_value=0)
        fig = px.imshow(tabla_pivote,
                        labels=dict(x="Actividad Física", y="Water", color="Frequency"),
                        x=tabla_pivote.columns,
                        y=tabla_pivote.index,
                        color_continuous_scale="Viridis",zmin=0, zmax=160)
        fig.update_layout(title=dict(text=f"<b>Heatmap para </b>", x=0.5))
        fig.show()
heatmap(obesidad_limpio)
# Out:
# <div>                            <div id="f675e696-3932-4f96-b0c6-d522b425d611" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f675e696-3932-4f96-b0c6-d522b425d611")) {                    Plotly.newPlot(                        "f675e696-3932-4f96-b0c6-d522b425d611",                        [{"coloraxis":"coloraxis","name":"0","x":["No hago","1d-2d","2d-4d","4d-5d"],"y":["Menos de 1L","1L-2L","M\u00e1s de 2L"],"z":[[205,154,99,8],[338,399,280,63],[150,201,111,46]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Actividad F\u00edsica: %{x}<br>Water: %{y}<br>Frequency: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %%
pd.pivot_table(obesidad_limpio[['water','alcohol']], aggfunc=len, index='water', columns='alcohol', fill_value=0)
# Out:
# alcohol       no  Sometimes  Frequently  Always
# water
# Menos de 1L  165        295           6       0
# 1L-2L        319        719          41       1
# Más de 2L    122        368          18       0

# %%
tabla_pivote = pd.pivot_table(obesidad_limpio[['physical_activity','water']], aggfunc=len, index='water', columns='physical_activity', fill_value=0)
tabla_pivote
# Out:
# physical_activity  No hago  1d-2d  2d-4d  4d-5d
# water
# Menos de 1L            205    154     99      8
# 1L-2L                  338    399    280     63
# Más de 2L              150    201    111     46

# %%
fig = px.imshow(tabla_pivote,
                        x=tabla_pivote.columns,
                        y=tabla_pivote.index,
                        color_continuous_scale="Viridis",zmin=0, zmax=160)
fig.show()
# Out:
# <div>                            <div id="ff3023ea-2493-46c2-875f-7f60a602af3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff3023ea-2493-46c2-875f-7f60a602af3e")) {                    Plotly.newPlot(                        "ff3023ea-2493-46c2-875f-7f60a602af3e",                        [{"coloraxis":"coloraxis","name":"0","x":["No hago","1d-2d","2d-4d","4d-5d"],"y":["Menos de 1L","1L-2L","M\u00e1s de 2L"],"z":[[205,154,99,8],[338,399,280,63],[150,201,111,46]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"physical_activity: %{x}<br>water: %{y}<br>color: %{z}<extra></extra>"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"h ...
